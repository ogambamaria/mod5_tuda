# %%
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertModel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import regex as re
import torch

# %%
data = pd.read_csv('data/clm_open_ended.csv')
data.head()
# Out:
#   Date of feedback collection  County Positive feedback on services  \
# 0         2024-04-17 20:55:46   Narok                          Good
# 1         2024-04-17 19:49:25  Kisumu       Quick service delivery
# 2         2024-04-17 19:44:28  Kisumu          Got drugs and happy
# 3         2024-04-17 19:37:41  Kisumu       Quick service delivery
# 4         2024-04-17 19:31:12  Kisumu   Good reception from medics
#
#   Negative feedback on services  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#       Suggestions for improving access to services  \
# 0                                To used hospital
# 1  Additional of medics to speed service delivery
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#              Positive aspects of facility to emulate  \
# 0                                     Good services
# 1                       Medics talk well to clients
# 2                           Good treatment services
# 3                          Good medication services
# 4  Medics are patient and have good listening ear...
#
#                  General suggestions for improvement  \
# 0                                               Time
# 1                                                NaN
# 2                                                NaN
# 3  Infrastructure development and add machines to...
# 4                            Quick service delivery
#
#   Top 1-3 Positive aspects of care and treatment  \
# 0                                     Awareness
# 1                        Quick service delivery
# 2                           Got drugs and happy.
# 3                        Quick service delivery
# 4                    Good reception from medics
#
#   Top 1-3 Negative aspects of care and treatment
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN

# %%
data.shape
# Out:
# (60749, 9)

# %%
data.drop(['Date of feedback collection', 'County'], axis=1, inplace=True)

# %%
df = data.dropna()
print('Original dataset shape: ', data.shape)
print('Cleaned dataset shape: ', df.shape)
# Out:
# Original dataset shape:  (60749, 7)
# Cleaned dataset shape:  (21123, 7)

# %%
df['combined_feedback'] = df[['Positive feedback on services', 'Negative feedback on services', 'Suggestions for improving access to services', 'Positive aspects of facility to emulate', 'General suggestions for improvement']].agg('. '.join, axis=1)
df
# Out:
# C:\Users\Maria\AppData\Local\Temp\ipykernel_11904\2398499216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['combined_feedback'] = df[['Positive feedback on services', 'Negative feedback on services', 'Suggestions for improving access to services', 'Positive aspects of facility to emulate', 'General suggestions for improvement']].agg('. '.join, axis=1)
#                            Positive feedback on services  \
# 14                         Good handling from the staff
# 15                        Good reception from the staff
# 16                        Good reception from the staff
# 17                         Good handling from the staff
# 18            Staff are very friendly and understanding
# ...                                                  ...
# 60739                                   Friendly staffs
# 60743                                       All are good
# 60745  At least pmtct is screened and nutrition couns...
# 60746                                       All are well
# 60747                                    PMTCT done well
#
#       Negative feedback on services  \
# 14                            None
# 15                            None
# 16                            None
# 17                            None
# 18                            None
# ...                             ...
# 60739     Referral for the service
# 60743                 Nothing wrong
# 60745                      Nothing
# 60746                      Nothing
# 60747               Nothing at all
#
#       Suggestions for improving access to services  \
# 14                                  More medicine
# 15                                     More staff
# 16                                     More staff
# 17                                  More medicine
# 18                                  More medicine
# ...                                            ...
# 60739               Making All services available
# 60743                                      No idea
# 60745                                      no idea
# 60746                                      No idea
# 60747                                     No idea
#
#                  Positive aspects of facility to emulate  \
# 14     Good follow up with the clients through phone ...
# 15             Good communication skills from the staff
# 16     Constant reminder through phone calls on appoi...
# 17     Good reception and communication skills from t...
# 18                Staff are very friendly and welcoming
# ...                                                  ...
# 60739                                   Friendly staffs
# 60743  Good communication skills by staffs and confid...
# 60745                            Good treatment and care
# 60746                                          good care
# 60747                                        Good staffs
#
#       General suggestions for improvement  \
# 14                         More medicine
# 15                         More medicine
# 16     More medicine especially septrine
# 17     More medicine especially septrine
# 18     More medicine especially septrine
# ...                                   ...
# 60739                 Nutrition services
# 60743                             No idea
# 60745                            No idea
# 60746                            Nothing
# 60747                            No idea
#
#           Top 1-3 Positive aspects of care and treatment  \
# 14                              Puctuality of the staff
# 15                        Good reception from the staff
# 16                              Staff are very reliable
# 17                Availability of staff in the facility
# 18                        Facility is easily accessible
# ...                                                  ...
# 60739  ARTS available, lab services available and sta...
# 60743                                    Good treatment
# 60745                              I like the pmtct part
# 60746                                    Good treatment
# 60747           Good treatment and prescription of meds
#
#           Top 1-3 Negative aspects of care and treatment  \
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# ...                                                  ...
# 60739  Overcrowded wards for inpatient clients, poor ...
# 60743                                           Nothing
# 60745                                           Nothing
# 60746         Nothing wrong seen at all services points
# 60747                                Nothing wrong seen
#
#                                        combined_feedback
# 14     Good handling from the staff . None . More med...
# 15     Good reception from the staff . None . More st...
# 16     Good reception from the staff . None . More st...
# 17     Good handling from the staff . None . More med...
# 18     Staff are very friendly and understanding . No...
# ...                                                  ...
# 60739  Friendly staffs . Referral for the service . M...
# 60743  All are good. Nothing wrong. No idea. Good com...
# 60745  At least pmtct is screened and nutrition couns...
# 60746  All are well. Nothing . No idea. good care. No...
# 60747  PMTCT done well. Nothing at all . No idea . Go...
#
# [21123 rows x 8 columns]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize the feedback
def tokenize_feedback(text):
    encoded = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=512,
        return_token_type_ids=False,
        padding='max_length',
        return_attention_mask=True,
        return_tensors='pt',  # Returns PyTorch tensors
        truncation=True
    )
    return encoded['input_ids'], encoded['attention_mask']

# Apply tokenizer to the DataFrame
df['tokens'] = df['combined_feedback'].apply(lambda x: tokenize_feedback(x))
print(df['tokens'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 18
#      15     return encoded['input_ids'], encoded['attention_mask']
#      17 # Apply tokenizer to the DataFrame
# ---> 18 df['tokens'] = df['combined_feedback'].apply(lambda x: tokenize_feedback(x))
#      19 print(df['tokens'])
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[53], line 18, in <lambda>(x)
#      15     return encoded['input_ids'], encoded['attention_mask']
#      17 # Apply tokenizer to the DataFrame
# ---> 18 df['tokens'] = df['combined_feedback'].apply(lambda x: tokenize_feedback(x))
#      19 print(df['tokens'])
#
# Cell In[53], line 5, in tokenize_feedback(text)
#       4 def tokenize_feedback(text):
# ----> 5     encoded = tokenizer.encode_plus(
#       6         text,
#       7         add_special_tokens=True,
#       8         max_length=512,
#       9         return_token_type_ids=False,
#      10         padding='max_length',
#      11         return_attention_mask=True,
#      12         return_tensors='pt',  # Returns PyTorch tensors
#      13         truncation=True
#      14     )
#      15     return encoded['input_ids'], encoded['attention_mask']
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:3037, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3027 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3028 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3029     padding=padding,
#    3030     truncation=truncation,
#    (...)
#    3034     **kwargs,
#    3035 )
# -> 3037 return self._encode_plus(
#    3038     text=text,
#    3039     text_pair=text_pair,
#    3040     add_special_tokens=add_special_tokens,
#    3041     padding_strategy=padding_strategy,
#    3042     truncation_strategy=truncation_strategy,
#    3043     max_length=max_length,
#    3044     stride=stride,
#    3045     is_split_into_words=is_split_into_words,
#    3046     pad_to_multiple_of=pad_to_multiple_of,
#    3047     return_tensors=return_tensors,
#    3048     return_token_type_ids=return_token_type_ids,
#    3049     return_attention_mask=return_attention_mask,
#    3050     return_overflowing_tokens=return_overflowing_tokens,
#    3051     return_special_tokens_mask=return_special_tokens_mask,
#    3052     return_offsets_mapping=return_offsets_mapping,
#    3053     return_length=return_length,
#    3054     verbose=verbose,
#    3055     **kwargs,
#    3056 )
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\transformers\tokenization_utils.py:722, in PreTrainedTokenizer._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     719 first_ids = get_input_ids(text)
#     720 second_ids = get_input_ids(text_pair) if text_pair is not None else None
# --> 722 return self.prepare_for_model(
#     723     first_ids,
#     724     pair_ids=second_ids,
#     725     add_special_tokens=add_special_tokens,
#     726     padding=padding_strategy.value,
#     727     truncation=truncation_strategy.value,
#     728     max_length=max_length,
#     729     stride=stride,
#     730     pad_to_multiple_of=pad_to_multiple_of,
#     731     return_tensors=return_tensors,
#     732     prepend_batch_axis=True,
#     733     return_attention_mask=return_attention_mask,
#     734     return_token_type_ids=return_token_type_ids,
#     735     return_overflowing_tokens=return_overflowing_tokens,
#     736     return_special_tokens_mask=return_special_tokens_mask,
#     737     return_length=return_length,
#     738     verbose=verbose,
#     739 )
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:3527, in PreTrainedTokenizerBase.prepare_for_model(self, ids, pair_ids, add_special_tokens, padding, truncation, max_length, stride, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, prepend_batch_axis, **kwargs)
#    3524 if return_length:
#    3525     encoded_inputs["length"] = len(encoded_inputs["input_ids"])
# -> 3527 batch_outputs = BatchEncoding(
#    3528     encoded_inputs, tensor_type=return_tensors, prepend_batch_axis=prepend_batch_axis
#    3529 )
#    3531 return batch_outputs
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:224, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     220     n_sequences = encoding[0].n_sequences
#     222 self._n_sequences = n_sequences
# --> 224 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File c:\Users\Maria\Desktop\School\mod5_tuda\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:713, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     711 elif tensor_type == TensorType.PYTORCH:
#     712     if not is_torch_available():
# --> 713         raise ImportError("Unable to convert output to PyTorch tensors format, PyTorch is not installed.")
#     714     import torch
#     716     is_tensor = torch.is_tensor
#
# ImportError: Unable to convert output to PyTorch tensors format, PyTorch is not installed.

# %%
# Load BERT model
model = BertModel.from_pretrained('bert-base-uncased')

# Function to get BERT embeddings
def get_bert_embeddings(tokens):
    model.eval()
    with torch.no_grad():
        outputs = model(tokens[0], attention_mask=tokens[1])
        embeddings = outputs.last_hidden_state[:, 0, :].numpy()
    return embeddings

# Apply the function to get embeddings
df['embeddings'] = df['tokens'].apply(get_bert_embeddings)

# Concatenate all embeddings into a matrix for clustering
all_embeddings = np.vstack(df['embeddings'].values)

# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(all_embeddings)

# Perform PCA to reduce dimensionality for better clustering
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X_scaled)

# Clustering
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(X_pca)
df['topic'] = kmeans.labels_

# %%
# Placeholder for summary
# This is a pseudo code. You would need a fine-tuned BERT sequence-to-sequence model for summarization
df['summary'] = df['combined_feedback'].apply(lambda x: 'Summarized text here')

# %%
# Analyze the topics and summaries
df[['combined_feedback', 'topic', 'summary']]
